# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("seaborn-white")
data = np.random.randn(1000)


plt.hist(data)
# Out:
# (array([ 19.,  58., 168., 258., 265., 149.,  64.,  15.,   3.,   1.]),
#  array([-2.89854581, -2.18328684, -1.46802786, -0.75276889, -0.03750992,
#          0.67774905,  1.39300803,  2.108267  ,  2.82352597,  3.53878495,
#          4.25404392]),
#  <BarContainer object of 10 artists>)

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1.8, 1000)
x3 = np.random.normal(3, 2.8, 1000)

kwargs = dict(histtype="stepfilled", alpha=0.3, bins=40)


plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([ 1.,  0.,  2.,  1.,  9.,  8.,  8., 12., 19., 14., 18., 29., 35.,
#         42., 43., 50., 48., 50., 56., 57., 62., 51., 61., 46., 39., 43.,
#         33., 32., 28., 26., 15., 20., 11., 14.,  3.,  4.,  1.,  6.,  0.,
#          3.]),
#  array([-5.10866749, -4.70260424, -4.296541  , -3.89047775, -3.48441451,
#         -3.07835126, -2.67228802, -2.26622477, -1.86016153, -1.45409828,
#         -1.04803504, -0.64197179, -0.23590855,  0.1701547 ,  0.57621794,
#          0.98228119,  1.38834443,  1.79440768,  2.20047092,  2.60653417,
#          3.01259741,  3.41866066,  3.8247239 ,  4.23078715,  4.63685039,
#          5.04291364,  5.44897688,  5.85504013,  6.26110337,  6.66716662,
#          7.07322987,  7.47929311,  7.88535636,  8.2914196 ,  8.69748285,
#          9.10354609,  9.50960934,  9.91567258, 10.32173583, 10.72779907,
#         11.13386232]),
#  [<matplotlib.patches.Polygon at 0x1e5cff9ca60>])

# %%
# two dimensional histograms

mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

plt.hist2d(x, y, bins=30, cmap="Blues")
cb = plt.colorbar()
cb.set_label("counts in bin")
